# %%
print("Alo Mundo")
# Out:
# Alo Mundo

# %% [markdown]
# Entender a inteligência artificial, além das ferramentas tem suas vantagens:
#
# - Você pode aprender a criar suas próprias soluções
# - Criar startups e empresas inovadoras
# - Pode apresentar as soluções prontas com autoridade
# - Pode utilizar-se de modelos pré-treinados
# - Preparar o currículo para novos empregos e oportunidades
# - Se atualizar de novos recursos tecnológicos

# %% [markdown]
# {
#   "cep": "72007-260",
#   "logradouro": "Rua Rua 10",
#   "complemento": "",
#   "unidade": "",
#   "bairro": "Setor Habitacional Vicente Pires",
#   "localidade": "Brasília",
#   "uf": "DF",
#   "estado": "Distrito Federal",
#   "regiao": "Centro-Oeste",
#   "ibge": "5300108",
#   "gia": "",
#   "ddd": "61",
#   "siafi": "9701"
# }

# %%
! pip install pandas requests

# %%
! pip install lxml

# %%
! pip install html5lib

# %%
! pip install beautifulsoup4

# %%
import pandas as pd
import requests

# %%
url = "file.json"

# %%
data = requests.get("https://viacep.com.br/ws/72007260/json/")
data_arquivo = data.json()
df = pd.DataFrame(data_arquivo,index=[0])
df.head()
# Out:
#          cep  logradouro complemento unidade  \
# 0  72007-260  Rua Rua 10
#
#                              bairro localidade  uf            estado  \
# 0  Setor Habitacional Vicente Pires   Brasília  DF  Distrito Federal
#
#          regiao     ibge gia ddd siafi
# 0  Centro-Oeste  5300108      61  9701

# %%
df = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# - Motivaçao

# %% [markdown]
# - Fisica

# %% [markdown]
# - IA para encapsular funçoes e aumentar o processamento de dados

# %% [markdown]
# - Jogos

# %%
df["variety"].value_counts()
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %% [markdown]
# - Liste Comprehension

# %%
! pip install matplotlib

# %%
# Aplicaçao do List Comprehension
# [] - List
# string --> s
# Trocar o '.' por '_' , boa pratica para nao bugar algumas funçoes
df.columns = [s.replace('.','_') for s in df.columns]

# %%
df_Setosa = df.query('variety == "Setosa"').copy()
df_versicolor = df.query('variety== "Versicolor"').copy()
df_Virginica = df.query('variety == "Virginica"').copy()

medidas = ['sepal_length','sepal_width','petal_length','petal_width']

# %%
df_Setosa[medidas].hist(color = "purple")
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df_Virginica[medidas].hist(color="green")
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df_versicolor[medidas].hist(color="orange")
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %% [markdown]
# - Poder preditivo

# %%
df.query('petal_length > 5')['variety'].value_counts()
# Out:
# variety
# Virginica     41
# Versicolor     1
# Name: count, dtype: int64

# %%
df.query('petal_length > 5')['variety'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Inteligencia Artificial

# %% [markdown]
# - Maquinas que imitam comportamentos humanos
# - Esse conceito é geral (Guarda-chuva)
# - Maquinas e softwares que tomam decisoes e podem prever o futuro.
# - Maquinas inteligentes que podem executar desde tarefas simples de automaçao
# ate um humano em uma partida de xadrez.

# %% [markdown]
# - Aprendizado de Máquina

# %% [markdown]
# - Machine Learning
# - Area dentro da IA
# - Pode ser visto como uma area dentro da Inteligência Artificial
# e se refere a tecnicas para construir conhecimento (estimar funçoes) a partir de observaçoes (0.1)- variaveis
# explicativas,variavel target(Alvo)

# %% [markdown]
# - Aprendizado Profundo

# %% [markdown]
# ## Redes Neurais
# ## Deep Learning
# ## Neurociencia

# %% [markdown]
# ![image.png](attachment:image.png)
